# %%
import pandas as pd

# %%
d=pd.read_csv('/content/drive/MyDrive/Life Expectancy Data.csv')

# %%
print(d)
# Out:
#           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]

# %%
print(d.head)
# Out:
# <bound method NDFrame.head of           Country  Year  ... Income composition of resources  Schooling
# 0     Afghanistan  2015  ...                           0.479       10.1
# 1     Afghanistan  2014  ...                           0.476       10.0
# 2     Afghanistan  2013  ...                           0.470        9.9
# 3     Afghanistan  2012  ...                           0.463        9.8
# 4     Afghanistan  2011  ...                           0.454        9.5
# ...           ...   ...  ...                             ...        ...
# 2933     Zimbabwe  2004  ...                           0.407        9.2
# 2934     Zimbabwe  2003  ...                           0.418        9.5
# 2935     Zimbabwe  2002  ...                           0.427       10.0
# 2936     Zimbabwe  2001  ...                           0.427        9.8
# 2937     Zimbabwe  2000  ...                           0.434        9.8
#
# [2938 rows x 22 columns]>

# %%
from matplotlib import  pyplot as plt

# %%
x=d['Adult Mortality']
y=d['Life expectancy ']
plt.scatter(x,y)

# %%
x=d['infant deaths']
y=d['Life expectancy ']
plt.scatter(x,y)

# %%
x=d['Alcohol']
y=d['Life expectancy ']
plt.scatter(x,y)

# %%
x=d['percentage expenditure']
y=d['Life expectancy ']
plt.scatter(x,y)

# %%
x=d['Hepatitis B']
y=d['Life expectancy ']
plt.scatter(x,y)
